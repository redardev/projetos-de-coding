# %%
idade1 = 72

# %%
idade2 = 35

# %%
idade1+ idade2
# Out:
# 107

# %%
somaIdade = idade1 + idade2

# %%
idade2 - idade1
# Out:
# -37

# %%
idade1 * idade2
# Out:
# 2520

# %%
idade2 / idade1
# Out:
# 0.4861111111111111

# %%
idade1 + 10
# Out:
# 82

# %%
idade2 - 15
# Out:
# 20

# %%
somaIdade * 2
# Out:
# 214

# %%
idade1 / 4
# Out:
# 18.0

# %%
calculo2= 2 * idade1 + 3 * idade2 / 4
# Out:
# 170.25

# %%
calculo3= (2 * idade1 + 3 * idade2) / 4
# Out:
# 62.25

# %%
calculo1 = 2*(idade1+idade2)

# %%
idade1 **2315
# Out:
# ...

# %%
nome= 'Bernardo'
sobrenome= ' Serrano'
print (nome + sobrenome)
# Out:
# Bernardo Serrano

# %%
print ('olá,', nome,'\n'  'você tem ', idade1 - 55, 'anos. ')
# Out:
# olá, Bernardo
# você tem  17 anos.

# %%
input('digite seu nome')
# Out:
# 'Manoel gomes'

# %%
idade= int(input('digite sua idade')) 
print (idade)
# Out:
# 17

# %%
type(idade)
# Out:
# int

# %%
dia = "quinta feira"
dia = 32,5
print(dia)
dia = 19
# Out:
# (32, 5)
